# %%
# %run /Users/dhanashreedani26@gmail.com/Final_project/logging

# %%
# use at the end
# logs_df = spark.createDataFrame(log_records, ["timestamp", "level", "message"])
# logs_df.write.format("delta") \
#     .mode("append") \
#     .save("abfss://silver@storefinalproject.dfs.core.windows.net/logs/etl_logs")

# %%
dbutils.fs.ls("abfss://bronze@storefinalproject.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://bronze@storefinalproject.dfs.core.windows.net/retail_inventory/', name='retail_inventory/', size=0, modificationTime=1775025635000)]

# %%
dbutils.fs.ls("abfss://bronze@storefinalproject.dfs.core.windows.net/retail_inventory/")
# Out:
# [FileInfo(path='abfss://bronze@storefinalproject.dfs.core.windows.net/retail_inventory/retail_inventory_data', name='retail_inventory_data', size=44090, modificationTime=1775025635000)]

# %%
try:
    log_message("INFO","Reading data from Bronze")

    df = spark.read.option("multiline", "true").json(
        "abfss://bronze@storefinalproject.dfs.core.windows.net/retail_inventory/retail_inventory_data"
    )

    log_message("INFO", "Data loaded successfully")

except Exception as e:
    log_message("ERROR",f"Ingestion failed: {str(e)}")
    raise
# Out:
# INFO: Reading data from Bronze
# INFO: Data loaded successfully

# %%
df.display()

log_message("INFO","API data ingestion successful (data available in Bronze)")
# Out:
# Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
