# %%
# %run /Users/shreya.dani22@gmail.com/Final_project/Logging

# %%
log_message("INFO", "ext_loc_catalog notebook started")
# Out:
# 2026-04-07 09:51:57,813 INFO Received command c on object id p0
# Received command c on object id p0
# INFO: ext_loc_catalog notebook started

# %%
# %sql
CREATE EXTERNAL LOCATION if not EXISTS ext_loc_bronze
URL 'abfss://bronze@finalprojstore.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL project_cred);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "External location 'ext_loc_bronze' created at abfss://bronze@finalprojstore.dfs.core.windows.net/")
# Out:
# INFO: External location 'ext_loc_bronze' created at abfss://bronze@finalprojstore.dfs.core.windows.net/

# %%
# %sql
CREATE EXTERNAL LOCATION if not EXISTS ext_loc_silver
URL 'abfss://silver@finalprojstore.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL project_cred);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "External location 'ext_loc_silver' created at abfss://silver@finalprojstore.dfs.core.windows.net/")
# Out:
# INFO: External location 'ext_loc_silver' created at abfss://silver@finalprojstore.dfs.core.windows.net/

# %%
# %sql
CREATE EXTERNAL LOCATION if not EXISTS ext_loc_gold
URL 'abfss://gold@finalprojstore.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL project_cred);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "External location 'ext_loc_gold' created at abfss://gold@finalprojstore.dfs.core.windows.net/")
# Out:
# Received command c on object id p0
# INFO: External location 'ext_loc_gold' created at abfss://gold@finalprojstore.dfs.core.windows.net/

# %%
# %sql
CREATE CATALOG if not EXISTS retail_catalog;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "Catalog 'retail_catalog' created successfully")
# Out:
# INFO: Catalog 'retail_catalog' created successfully

# %%
# %sql
CREATE SCHEMA if not EXISTS retail_catalog.retail_schema;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "Schema 'retail_catalog.retail_schema' created successfully")
# Out:
# INFO: Schema 'retail_catalog.retail_schema' created successfully

# %%
# %sql
USE retail_catalog.retail_schema;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
log_message("INFO", "Switched to retail_catalog.retail_schema")
log_message("INFO", "ext_loc_catalog notebook completed successfully")
# Out:
# INFO: Switched to retail_catalog.retail_schema
# INFO: ext_loc_catalog notebook completed successfully
